# %%
import pandas as pd
df = pd.read_csv("C:/Users/dd_18/Documents/Python_para_data_science/DataScience_notes/2008.csv", nrows=1e6)
# Carga un millon de datos nrows = 1e6

# %%
dfduplicate = pd.concat([df, df])
#dfduplicate = df.append(df) #data frame con todos los datos duplicados

#NOTA: debido a que el método append fue deprecado desde pandas 2.0, se usa en su lugar la función concat()

# %%
dfduplicate = dfduplicate.sample(frac=1) #reordenado

# %%
# Gestion de datos duplicados
dfclean = dfduplicate.drop_duplicates() # eliminando los datos duplicados del data frame y asignandolo a uno nuevo

# %%
len(dfclean) == len(df) # El numero de filas del nuevo data frame es distinto al numero de filas del original
# Out:
# False

# %%
len(dfclean) # el nuevo df tiene 4 filas menos que el original
# Estos se debe a que el original tenia en si mismo datos duplicados
# Out:
# 999996

# %%
dfclean.drop_duplicates(subset= "DayofMonth") # El parametro subset le indica la columna sobre la que busca duplicados
#Unicamente eliminará filas en las que el dato de DayofMonth esta duplicado
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime
# 184381  2008      1          10          4    945.0         908   1035.0  \
# 680750  2008      2          25          1   1838.0        1835   1958.0
# 697120  2008      2           8          5   1318.0        1300   1552.0
# 155422  2008      1           9          3   1700.0        1650   1815.0
# 112283  2008      1           5          6    600.0         600    833.0
# 794449  2008      2          19          2   1459.0        1429   1634.0
# 938492  2008      2          29          5    652.0         700    832.0
# 341209  2008      1           2          3   1950.0        1850   1948.0
# 860507  2008      2          11          1   2000.0        2000   2128.0
# 675835  2008      2          24          7   2043.0        2005   2143.0
# 302260  2008      1           3          4    806.0         805    822.0
# 946243  2008      2          12          2   1133.0        1117   1423.0
# ...

# %%
#Gestion de datos faltantes
df.dropna() # se obtiene un data frame vacio porque todas las filas tienen al menos un dato faltente
# porque si el vuelo esta cancelado no tiene hora de llegada y si tiene hora de llegada no esta cancelado
# Out:
# Empty DataFrame
# Columns: [Year, Month, DayofMonth, DayOfWeek, DepTime, CRSDepTime, ArrTime, CRSArrTime, UniqueCarrier, FlightNum, TailNum, ActualElapsedTime, CRSElapsedTime, AirTime, ArrDelay, DepDelay, Origin, Dest, Distance, TaxiIn, TaxiOut, Cancelled, CancellationCode, Diverted, CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, LateAircraftDelay]
# Index: []
#
# [0 rows x 29 columns]

# %%
df.dropna(thresh= 25) 
# thres especifica cuantas entradas de todas las columnas queremos que esten llenas de informacion relevante
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime
# 4       2008      1           3          4   1829.0        1755   1959.0  \
# 6       2008      1           3          4   1937.0        1830   2037.0
# 11      2008      1           3          4   1644.0        1510   1845.0
# 16      2008      1           3          4   1452.0        1425   1640.0
# 18      2008      1           3          4   1323.0        1255   1526.0
# ...      ...    ...         ...        ...      ...         ...      ...
# 999973  2008      2          23          6   1306.0        1235   1514.0
# 999983  2008      2          28          4   1458.0        1235   1645.0
# 999988  2008      2           4          1   1754.0        1655   2056.0
# 999989  2008      2           5          2   1812.0        1655   2129.0
# 999994  2008      2          11          1   1717.0        1655   2030.0
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled
# ...

# %%
df.dropna(thresh=len(df.columns)-2) # maximo dos valores faltantes
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime
# 4       2008      1           3          4   1829.0        1755   1959.0  \
# 6       2008      1           3          4   1937.0        1830   2037.0
# 11      2008      1           3          4   1644.0        1510   1845.0
# 16      2008      1           3          4   1452.0        1425   1640.0
# 18      2008      1           3          4   1323.0        1255   1526.0
# ...      ...    ...         ...        ...      ...         ...      ...
# 999973  2008      2          23          6   1306.0        1235   1514.0
# 999983  2008      2          28          4   1458.0        1235   1645.0
# 999988  2008      2           4          1   1754.0        1655   2056.0
# 999989  2008      2           5          2   1812.0        1655   2129.0
# 999994  2008      2          11          1   1717.0        1655   2030.0
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled
# ...

# %%
df.dropna(subset= ["CancellationCode"]) # con subset le especificas la columna en la que no quieres datos faltantes
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime
# 178     2008      1           3          4      NaN         700      NaN  \
# 373     2008      1           3          4      NaN        1100      NaN
# 399     2008      1           3          4      NaN         905      NaN
# 401     2008      1           3          4      NaN        1620      NaN
# 415     2008      1           3          4      NaN        1930      NaN
# ...      ...    ...         ...        ...      ...         ...      ...
# 999913  2008      2          11          1      NaN         855      NaN
# 999919  2008      2          17          7      NaN         855      NaN
# 999961  2008      2          17          7      NaN        1445      NaN
# 999971  2008      2          22          5      NaN        1235      NaN
# 999999  2008      2          17          7      NaN        1655      NaN
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled
# ...
