# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/dd_18/Documents/Python_para_data_science/DataScience_notes/2008.csv", nrows = 100000)

# %% [markdown]
# Se suele usar pd como alias para Panda y df (data frame) para la variable de la base de datos
# Para que la ruta del archivo sea leida correctamente, hay que pasar los \ usados en rutas de windows a /, o agregar una r antes del string de la ruta de windows

# %%
df.head(10) # Permite explorar la parte superior de el df
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime
# 0  2008      1           3          4   2003.0        1955   2211.0  \
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
# 5  2008      1           3          4   1940.0        1915   2121.0
# 6  2008      1           3          4   1937.0        1830   2037.0
# 7  2008      1           3          4   1039.0        1040   1132.0
# 8  2008      1           3          4    617.0         615    652.0
# 9  2008      1           3          4   1620.0        1620   1639.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled
# 0        2225            WN        335  ...    4.0      8.0          0  \
# 1        1000            WN       3231  ...    5.0     10.0          0
# ...

# %% [markdown]
# Es importante recordar que el indice de las filas inicia siempre desde cero

# %%
df.tail() # Permite explorar la parte inferior del df
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime
# 99995  2008      1          25          5   2204.0        1935    106.0  \
# 99996  2008      1          26          6   1933.0        1935   2234.0
# 99997  2008      1          27          7   2047.0        1935   2400.0
# 99998  2008      1          28          1   1956.0        1935   2308.0
# 99999  2008      1          29          2   1938.0        1935   2308.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled
# 99995        2257            XE       7676  ...    4.0     17.0          0  \
# 99996        2257            XE       7676  ...    4.0     16.0          0
# 99997        2257            XE       7676  ...    6.0     18.0          0
# 99998        2257            XE       7676  ...    5.0     25.0          0
# 99999        2257            XE       7676  ...    5.0     41.0          0
#
#        CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay
# ...

# %%
df = df.sample(frac = 1) # si queremos ver el df desordenado, frac = 1 indica que lo queremos en el 100% de nuestro df

# %%
df
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime
# 34502  2008      1          13          7   1123.0        1125   1236.0  \
# 50073  2008      1          18          5   1652.0        1640   1751.0
# 43073  2008      1          16          3    732.0         730   1026.0
# 991    2008      1           3          4   1004.0         935   1142.0
# 85468  2008      1          29          2   1955.0        1955   2037.0
# ...     ...    ...         ...        ...      ...         ...      ...
# 23506  2008      1          10          4    736.0         730    912.0
# 13367  2008      1           7          1   1621.0        1550   1924.0
# 76845  2008      1          26          6   1410.0        1410   1454.0
# 12703  2008      1           7          1   1908.0        1905   2008.0
# 81503  2008      1          28          1   1507.0        1445   1741.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled
# ...

# %%
df.columns # Muestra los nombres de las columnas que tenemos en una lista
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %% [markdown]
# cuando se llama un atributo de el df no se agregan parentesis, por eso es df.columns  y no df.columns(). Cuando se aplica una funcion al df si se ponen parentesis

# %%
df.DepTime # muestra la columna DepTime entera
# Out:
# 34502    1123.0
# 50073    1652.0
# 43073     732.0
# 991      1004.0
# 85468    1955.0
#           ...
# 23506     736.0
# 13367    1621.0
# 76845    1410.0
# 12703    1908.0
# 81503    1507.0
# Name: DepTime, Length: 100000, dtype: float64

# %%
df.dtypes # muestra el tipo de variable asignado a cada columna
# Out:
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime         int64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# CancellationCode      object
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %%
df.values #devuelve todos los datos en un array, lo que facilita hacer operaciones matriciales por ejemplo
# Out:
# array([[2008, 1, 13, ..., nan, nan, nan],
#        [2008, 1, 18, ..., nan, nan, nan],
#        [2008, 1, 16, ..., nan, nan, nan],
#        ...,
#        [2008, 1, 26, ..., nan, nan, nan],
#        [2008, 1, 7, ..., nan, nan, nan],
#        [2008, 1, 28, ..., nan, nan, nan]], dtype=object)

# %%
df2 = df.head(10) #crear un nuevo data frame a partir del anterior

# %%
df2.head(20) #muestra unicamente 10 filas y no 20 porque solo tiene 10 filas
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 29095  2008      1          12          6    903.0         910    902.0
# 22232  2008      1          10          4   1055.0        1100   1152.0
# 47932  2008      1          17          4   1840.0        1840   2010.0
# 89068  2008      1          30          3   2012.0        2015   2228.0
# 70965  2008      1          24          4   1243.0        1230   1305.0
# 42060  2008      1          16          3   1509.0        1510   1619.0
# 48415  2008      1          17          4    916.0         910   1257.0
# 19133  2008      1           9          3    757.0         755    924.0
# 63472  2008      1          22          2   1254.0        1255   1422.0
# 5046   2008      1           4          5    940.0         940   1031.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 29095         910            WN        994  ...    4.0     11.0          0
# ...
